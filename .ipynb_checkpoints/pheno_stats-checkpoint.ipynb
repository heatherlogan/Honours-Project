# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# full paper phenotype distribution

data_path = os.path.join(os.getcwd(), 'files/stats/full_corpus_counts/',
                         'fullcorpus_pheno_stats.csv')

full_df = pd.read_csv(data_path)

# %%
group_keys = full_df.groupby('Group').size().keys()

print(group_keys)
# Out:
# Index(['Adaptive Life Skills', 'Cognitive Abilties', 'Comorbidities',
#        'Complaints and indications', 'Diagnosis', 'Emotional Traits',
#        'Executive Function', 'Exposures', 'Interpersonal Interactions',
#        'Language Ability', 'Medical History', 'Motor Skills',
#        'Perinatal History', 'Recognition of Social Norms', 'Social Competence',
#        'Stereotyped Restricted and Repetitive Behaviours'],
#       dtype='object', name='Group')

# %%
group_colours = [
    ('Perinatal History', '') ,
    ('Adaptive Life Skills', '') ,
    ('Cognitive Abilties', '') ,
    ('Comorbidities', '') ,
    ('Complaints and indications', '') ,
    ('Diagnosis', '') ,
    ('Emotional Traits', '') ,
    ('Executive Function', '') ,
    ('Exposures', '') ,
    ('Interpersonal Interactions', '') ,
    ('Language Ability', '') ,
    ('Motor Skills', '') ,
    ('Recognition of Social Norms', '') ,
    ('Stereotyped Restricted and Repetitive Behaviours', '') ,

]

# %%
# 0=medical, 1=personal, 2=social
group_tags = {
    'Perinatal History': 0 ,
    'Adaptive Life Skills':2 ,
    'Cognitive Abilties':1 ,
    'Comorbidities':0,
    'Complaints and indications':0 ,
    'Diagnosis': 0,
    'Personal Traits': 1,
    'Emotional Traits':1 ,
    'Executive Function':1 ,
    'Exposures':0,
    'Cognitive Abilities':1,
    'Interpersonal Interactions':2 ,
    'Language Ability':1,
    'Motor Skills':1 ,
    'Recognition of Social Norms':2,
    'Stereotyped Restricted and Repetitive Behaviours':2,
    'Social Competence':2,
    'Medical History':0
}

print(group_colours)
# Out:
# [('Perinatal History', ''), ('Adaptive Life Skills', ''), ('Cognitive Abilties', ''), ('Comorbidities', ''), ('Complaints and indications', ''), ('Diagnosis', ''), ('Emotional Traits', ''), ('Executive Function', ''), ('Exposures', ''), ('Interpersonal Interactions', ''), ('Language Ability', ''), ('Motor Skills', ''), ('Recognition of Social Norms', ''), ('Stereotyped Restricted and Repetitive Behaviours', '')]

# %%
colors = {0:'#7FB3D5', 1:'#BB8FCE', 2:'#F5CBA7'}

# %%
idx_list = []
for col in full_df.columns:
    if col == "Group":
        for i, row_value in full_df[col].iteritems():
            g = (group_tags[row_value])
            idx_list.append(g)
print(len(idx_list))

full_df['Group_idx'] = idx_list
# Out:
# 253

# %%
sorted_full = full_df.sort_values(['Group_idx', 'Group', 'RelevantCount'], 
                                  ascending=[True,True, False])

sorted_full
# Out:
#                                                  Label  \
# 160                                 Learning Disorders
# 140                                   Mental Disorders
# 211                                      Comorbidities
# 33                                   Anxiety Disorders
# 30                                 Depressive Disorder
# 145                                 Mental Retardation
# 51       Attention Deficit Disorder With Hyperactivity
# 171  Schizophrenia And Disorders With Psychotic Fea...
# 6                           Neurodegenerative Diseases
# 162                       Recognition of Social Norms     33             33
# 241                       Recognition of Social Norms     30             30
# 82                        Recognition of Social Norms     19             19
# 209                       Recognition of Social Norms     19             19
# 80                        Recognition of Social Norms      8              8
# 174                       Recognition of Social Norms      6              6
# 22                        Recognition of Social Norms      4              4
# 37                        Recognition of Social Norms      8              3
# 98                        Recognition of Social Norms      2              2
# 114                       Recognition of Social Norms      2              2
# 216                       Recognition of Social Norms      2              2
# 7                         Recognition of Social Norms      1              1
# 234                       Recognition of Social Norms      1              1
# 122                                 Social Competence    854            405
# 176  Stereotyped Restricted and Repetitive Behaviours    891            229
# 43   Stereotyped Restricted and Repetitive Behaviours    292             88
# 25   Stereotyped Restricted and Repetitive Behaviours    164             72
# 109  Stereotyped Restricted and Repetitive Behaviours     47             47
# 204  Stereotyped Restricted and Repetitive Behaviours     34             34
# 228  Stereotyped Restricted and Repetitive Behaviours     34             34
# 128  Stereotyped Restricted and Repetitive Behaviours    163             25
# 130  Stereotyped Restricted and Repetitive Behaviours     22             22
# 198  Stereotyped Restricted and Repetitive Behaviours     10             10
# 91   Stereotyped Restricted and Repetitive Behaviours      7              7
# 24   Stereotyped Restricted and Repetitive Behaviours      2              2
# 0    Stereotyped Restricted and Repetitive Behaviours      1              1
# 75   Stereotyped Restricted and Repetitive Behaviours      1              1
#
#      Group_idx
# 160          0
# 140          0
# 211          0
# 33           0
# 30           0
# 145          0
# 51           0
# 171          0
# 6            0
# 138          0
# 101          0
# 110          0
# 48           0
# 123          0
# 111          0
# 104          0
# 197          0
# 46           0
# 191          0
# 243          0
# 14           0
# 150          0
# 159          0
# 218          0
# 55           0
# 34           0
# 13           0
# 67           0
# 76           0
# 222          0
# ..         ...
# 240          2
# 134          2
# 1            2
# 162          2
# 241          2
# 82           2
# 209          2
# 80           2
# 174          2
# 22           2
# 37           2
# 98           2
# 114          2
# 216          2
# 7            2
# 234          2
# 122          2
# 176          2
# 43           2
# 25           2
# 109          2
# 204          2
# 228          2
# 128          2
# 130          2
# 198          2
# 91           2
# 24           2
# 0            2
# 75           2
#
# [253 rows x 5 columns]

# %%
colour_list = []
for col in full_df.columns:
    if col == "Group_idx":
        for i, row_value in full_df[col].iteritems():
            colour_list.append(colors[row_value])
            
print(colour_list)
# Out:
# ['#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#BB8FCE', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#F5CBA7', '#BB8FCE', '#7FB3D5', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#F5CBA7', '#F5CBA7', '#7FB3D5', '#7FB3D5', '#BB8FCE', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#7FB3D5']

# %%
fig, ax = plt.subplots(figsize=(20,50))

plt.scatter(sorted_full['RelevantCount'], sorted_full['Label'], color=colour_list)

# %%
groups = sorted_full.groupby("Group").sum().reset_index()

idx_list = [] 
for col in groups.columns:
    if col == "Group":
        for i, row_value in groups[col].iteritems():
            g = (group_tags[row_value])
            idx_list.append(g)

groups["Group Idx"] = idx_list

# %%
sort_groups = groups.sort_values(["Group Idx", "Count"], ascending=[False,False])

colour_list = []
for col in sort_groups.columns:
    if col == "Group Idx":
        for i, row_value in sort_groups[col].iteritems():
            colour_list.append(colors[row_value])
            
print(colour_list)
# Out:
# ['#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5']

# %%
sort_groups

fig, ax = plt.subplots(figsize=(10,15))

plt.barh( sort_groups['Group'],sort_groups['RelevantCount'], color=colour_list)

plt.show()

# %%
sort_groups

fig, ax = plt.subplots(figsize=(10,15))

plt.barh( sort_groups['Group'],sort_groups['Count'], color=colour_list)

plt.show()

# %%
# gene counts
data_path_gene = os.path.join(os.getcwd(), 'files/stats/gene_papers/',
                         'genepaper_pheno_counts.csv')

gene_df = pd.read_csv(data_path_gene)

# %%
gene_groups = gene_df.groupby("Group").sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-994cacb7bf0c> in <module>
#      10 gene_groups["Group Idx"] = idx_list
#      11
# ---> 12 gene_groups = gene_groups.sort_values(['Group Idx', 'RelevantCount'], ascending=[False,False])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4718
#    4719             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4720                     for x in by]
#    4721             indexer = lexsort_indexer(keys, orders=ascending,
#    4722                                       na_position=na_position)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4718
#    4719             keys = [self._get_label_or_level_values(x, axis=axis)
# -> 4720                     for x in by]
#    4721             indexer = lexsort_indexer(keys, orders=ascending,
#    4722                                       na_position=na_position)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1695             values = self.axes[axis].get_level_values(key)._values
#    1696         else:
# -> 1697             raise KeyError(key)
#    1698
#    1699         # Check for duplicates
#
# KeyError: 'RelevantCount'

# %%
colour_list_g = []
for col in gene_groups.columns:
    if col == "Group Idx":
        for i, row_value in gene_groups[col].iteritems():
            colour_list_g.append(colors[row_value])
            
print(colour_list_g)
# Out:
# ['#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5']

# %%
sort_groups

fig, ax = plt.subplots(figsize=(10,15))

plt.barh( gene_groups['Group'],gene_groups['Count'], color=colour_list_g)

plt.show()

# %%
sort_groups

fig, ax = plt.subplots(figsize=(10,15))

plt.barh( gene_groups['Group'],gene_groups['RelevantCount'], color=colour_list_g)

plt.show()

# %%
# PHENO COUNTRS
data_path_pheno = os.path.join(os.getcwd(), 'files/stats/pheno_papers/',
                         'phenopaper_pheno_counts.csv')

pheno_df = pd.read_csv(data_path_pheno)

# %%
pheno_groups = pheno_df.groupby("Group").sum().reset_index()

idx_list = [] 
for col in pheno_groups.columns:
    if col == "Group":
        for i, row_value in pheno_groups[col].iteritems():
            g = (group_tags[row_value])
            idx_list.append(g)

pheno_groups["Group Idx"] = idx_list

pheno_groups = pheno_groups.sort_values(['Group Idx', 'RelevantCount'], ascending=[False,False])

# %%
colour_list_p = []
for col in pheno_groups.columns:
    if col == "Group Idx":
        for i, row_value in pheno_groups[col].iteritems():
            colour_list_p.append(colors[row_value])
            
print(colour_list_p)
# Out:
# ['#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#F5CBA7', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#BB8FCE', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5', '#7FB3D5']

# %%
fig, ax = plt.subplots(figsize=(10,15))

plt.barh( pheno_groups['Group'],pheno_groups['Count'], color=colour_list_p)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,15))

plt.barh( pheno_groups['Group'],pheno_groups['RelevantCount'], color=colour_list_p)

plt.show()
